# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from pprint import pprint
#from citipy import citipy
import random
import scipy.stats as sts
from api_keys import weather_api_key as wkey

# %% [markdown]
# ## Generate Cities List

# %%
"""As percentage of water on Earth is 71%, there is only 29% chance that searching for a city with random latitudes and 
longitudes will return an actual city, so instead of using citipy, I copied "worldcities.csv" file from citipy documentations,
then separated columns using Excel"""

world_cities_df = pd.read_csv('worldcities.csv')
# print(len(world_cities_df)) --> 46832

#Create cities_df as a subset from worldcities with rows randomly chosen based on a fixed seed
random.seed(4)
random_indices = random.sample(range(46832),600)
country = []
city = []
lat = []
lng = []
for index in random_indices:
    country.append(world_cities_df.loc[index,'Country'])
    city.append(world_cities_df.loc[index,'City'])
    lat.append(world_cities_df.loc[index,'Latitude'])
    lng.append(world_cities_df.loc[index,'Longitude'])
cities_df = pd.DataFrame({'Country':country, 'City':city, 'Latitude':lat, 'Longitude':lng})

#Add City-ID column

cities_df.reset_index(inplace=True)
cities_df = cities_df.rename(columns={'index':'City_ID'})
cities_df.head()
# Out:
#    City_ID Country        City   Latitude  Longitude
# 0        0      hu    csengele  46.542336  19.863584
# 1        1      ir     delijan  33.990500  50.683800
# 2        2      co       colon   1.191167 -76.968500
# 3        3      no  lyngseidet  69.583333  20.216667
# 4        4      pl  trzebiatow  54.059404  15.279377

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Testing OpenWeatherMap API response by city name and state code for first city in cities_df
url = f'https://api.openweathermap.org/data/2.5/weather?appid={wkey}'
city = 'csengele,hu'
params = {'q':city, 'units':'imperial'}
response = requests.get(url, params).json()
pprint(response)

#Getting maximum temperature instead of current temperature to compensate for the effect of different day or night times
max_temp = response['main']['temp_max']
humidity = response['main']['humidity']
cloudiness = response['clouds']['all']
wind_speed = response['wind']['speed']
date = response['dt']
# Out:
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': 46.5423, 'lon': 19.8636},
#  'dt': 1631657979,
#  'id': 3054287,
#  'main': {'feels_like': 59.23,
#           'grnd_level': 1006,
#           'humidity': 52,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 61,
#           'temp_max': 61,
#           'temp_min': 61},
#  'name': 'Csengele',
#  'sys': {'country': 'HU',
#          'id': 6666,
#          'sunrise': 1631679508,
#          'sunset': 1631724797,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 136, 'gust': 4.52, 'speed': 4.36}}

# %%
#Make API calls to collect data for all cities
url = f'https://api.openweathermap.org/data/2.5/weather?appid={wkey}'
cities_df['Max Temperature'] = ''
cities_df['Humidity'] = ''
cities_df['Cloudiness'] = ''
cities_df['Wind Speed'] = ''
cities_df['Date'] = ''
print('Beginning Data Retrieval')
print('----------------------------')
for index,row in cities_df.iterrows():
    city_name = row['City']
    state_code = row['Country']
    city = city_name+','+state_code
    params = {'q':city, 'units':'imperial'}
    response = requests.get(url,params).json()
    try:
        cities_df.loc[index,'Max Temperature'] = response['main']['temp_max']
        cities_df.loc[index,'Humidity'] = response['main']['humidity']
        cities_df.loc[index,'Cloudiness'] = response['clouds']['all']
        cities_df.loc[index,'Wind Speed'] = response['wind']['speed']
        cities_df.loc[index,'Date'] = response['dt']
        print(f'Processing Record {index} of cities_df | {city_name}')
    except KeyError:
        print('City not found. Skipping...')
        continue
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 0 of cities_df | csengele
# Processing Record 1 of cities_df | delijan
# Processing Record 2 of cities_df | colon
# Processing Record 3 of cities_df | lyngseidet
# Processing Record 4 of cities_df | trzebiatow
# Processing Record 5 of cities_df | storvorde
# Processing Record 6 of cities_df | datong
# Processing Record 7 of cities_df | sefophe
# Processing Record 8 of cities_df | kaliganj
# Processing Record 9 of cities_df | waitati
# Processing Record 10 of cities_df | ilovka
# Processing Record 11 of cities_df | patnagarh
# Processing Record 12 of cities_df | santa cruz do sul
# Processing Record 13 of cities_df | panzos
# Processing Record 14 of cities_df | salatrucu
# Processing Record 15 of cities_df | anuchino
# Processing Record 16 of cities_df | cintalapa
# Processing Record 17 of cities_df | kant
# City not found. Skipping...
# Processing Record 19 of cities_df | jardin
# Processing Record 20 of cities_df | barsi
# City not found. Skipping...
# Processing Record 22 of cities_df | nevele
# Processing Record 23 of cities_df | masaka
# Processing Record 24 of cities_df | baj baj
# Processing Record 25 of cities_df | guskhara
# Processing Record 26 of cities_df | kinlochleven
# Processing Record 27 of cities_df | ermua
# Processing Record 28 of cities_df | cervia
# Processing Record 29 of cities_df | peddapuram
# Processing Record 30 of cities_df | sirari
# Processing Record 31 of cities_df | san bartolo del llano
# Processing Record 32 of cities_df | ovalle
# Processing Record 33 of cities_df | svit
# Processing Record 34 of cities_df | cayon
# Processing Record 35 of cities_df | alma
# Processing Record 36 of cities_df | san lorenzo
# City not found. Skipping...
# Processing Record 38 of cities_df | kalianget
# Processing Record 39 of cities_df | guerande
# Processing Record 40 of cities_df | biak
# Processing Record 41 of cities_df | bochnia
# Processing Record 42 of cities_df | krishnagiri
# Processing Record 43 of cities_df | boshan
# Processing Record 44 of cities_df | glubokiy
# Processing Record 45 of cities_df | ula
# Processing Record 46 of cities_df | azul
# Processing Record 47 of cities_df | rajpur
# Processing Record 48 of cities_df | ostrovnoy
# Processing Record 49 of cities_df | durazno
# Processing Record 50 of cities_df | forli
# Processing Record 51 of cities_df | ion corvin
# Processing Record 52 of cities_df | muthill
# Processing Record 53 of cities_df | bacong
# City not found. Skipping...
# Processing Record 55 of cities_df | zheleznodorozhnyy
# Processing Record 56 of cities_df | palanpur
# City not found. Skipping...
# Processing Record 58 of cities_df | pulilan
# Processing Record 59 of cities_df | veriora
# City not found. Skipping...
# Processing Record 61 of cities_df | tabas
# Processing Record 62 of cities_df | bachhraon
# Processing Record 63 of cities_df | dois irmaos
# Processing Record 64 of cities_df | chene-bougeries
# Processing Record 65 of cities_df | imperatriz
# Processing Record 66 of cities_df | tagana-an
# Processing Record 67 of cities_df | namanga
# Processing Record 68 of cities_df | kunnamkulam
# Processing Record 69 of cities_df | rebrisoara
# Processing Record 70 of cities_df | vranje
# Processing Record 71 of cities_df | paradise
# Processing Record 72 of cities_df | minchinabad
# Processing Record 73 of cities_df | lorton
# Processing Record 74 of cities_df | bech-kleinmacher
# Processing Record 75 of cities_df | rees
# Processing Record 76 of cities_df | elk river
# Processing Record 77 of cities_df | northampton
# Processing Record 78 of cities_df | pilane
# Processing Record 79 of cities_df | anoling
# Processing Record 80 of cities_df | sangueya
# Processing Record 81 of cities_df | pidhaytsi
# Processing Record 82 of cities_df | lysychovo
# Processing Record 83 of cities_df | malapag
# Processing Record 84 of cities_df | kandi
# Processing Record 85 of cities_df | saint-pierre-des-corps
# Processing Record 86 of cities_df | ajijic
# Processing Record 87 of cities_df | la paz
# Processing Record 88 of cities_df | tosno
# Processing Record 89 of cities_df | soverato
# Processing Record 90 of cities_df | ordzhonikidze
# Processing Record 91 of cities_df | krasnyy bogatyr
# Processing Record 92 of cities_df | wallasey
# Processing Record 93 of cities_df | suf
# Processing Record 94 of cities_df | armenia
# Processing Record 95 of cities_df | schroeder
# Processing Record 96 of cities_df | ha giang
# Processing Record 97 of cities_df | la virtud
# City not found. Skipping...
# Processing Record 99 of cities_df | shkotovo
# Processing Record 100 of cities_df | wang saphung
# Processing Record 101 of cities_df | foldeak
# Processing Record 102 of cities_df | jevicko
# Processing Record 103 of cities_df | omura
# Processing Record 104 of cities_df | gien
# Processing Record 105 of cities_df | pune
# Processing Record 106 of cities_df | santa rita
# Processing Record 107 of cities_df | nieuwerkerken
# Processing Record 108 of cities_df | cruzeiro
# Processing Record 109 of cities_df | asuncion ixtaltepec
# Processing Record 110 of cities_df | kyle
# Processing Record 111 of cities_df | martigny
# City not found. Skipping...
# Processing Record 113 of cities_df | natchez
# Processing Record 114 of cities_df | kamogawa
# Processing Record 115 of cities_df | radisici
# Processing Record 116 of cities_df | bull savanna
# Processing Record 117 of cities_df | parlakimidi
# Processing Record 118 of cities_df | triggiano
# Processing Record 119 of cities_df | holsted
# Processing Record 120 of cities_df | north haven
# Processing Record 121 of cities_df | kokopo
# Processing Record 122 of cities_df | nazilli
# Processing Record 123 of cities_df | maplewood
# Processing Record 124 of cities_df | waterloo
# Processing Record 125 of cities_df | rupnagar
# Processing Record 126 of cities_df | adana
# Processing Record 127 of cities_df | fraserburgh
# Processing Record 128 of cities_df | maya
# Processing Record 129 of cities_df | rajur
# Processing Record 130 of cities_df | gunzburg
# Processing Record 131 of cities_df | medan
# Processing Record 132 of cities_df | kuah
# Processing Record 133 of cities_df | zeya
# Processing Record 134 of cities_df | aseri
# Processing Record 135 of cities_df | owase
# Processing Record 136 of cities_df | pavino
# Processing Record 137 of cities_df | gotzis
# Processing Record 138 of cities_df | gabriel leyva solano
# Processing Record 139 of cities_df | goianinha
# Processing Record 140 of cities_df | san fernando
# Processing Record 141 of cities_df | vitoria
# Processing Record 142 of cities_df | ixtlan
# Processing Record 143 of cities_df | el pueblito
# Processing Record 144 of cities_df | pipraich
# Processing Record 145 of cities_df | oktyabrskiy
# Processing Record 146 of cities_df | tianpeng
# Processing Record 147 of cities_df | mabilang
# Processing Record 148 of cities_df | gargalianoi
# Processing Record 149 of cities_df | candabong
# Processing Record 150 of cities_df | kalamata
# Processing Record 151 of cities_df | tello
# Processing Record 152 of cities_df | santa rita do sapucai
# Processing Record 153 of cities_df | soledade
# Processing Record 154 of cities_df | pelotas
# Processing Record 155 of cities_df | tarifa
# Processing Record 156 of cities_df | vysha
# Processing Record 157 of cities_df | kalispell
# Processing Record 158 of cities_df | warendorf
# Processing Record 159 of cities_df | hangha
# Processing Record 160 of cities_df | carinhanha
# Processing Record 161 of cities_df | ekhabi
# Processing Record 162 of cities_df | atid
# Processing Record 163 of cities_df | sirtich
# Processing Record 164 of cities_df | katobu
# Processing Record 165 of cities_df | trani
# City not found. Skipping...
# Processing Record 167 of cities_df | jirkov
# Processing Record 168 of cities_df | vata de jos
# Processing Record 169 of cities_df | rayadrug
# Processing Record 170 of cities_df | vice
# Processing Record 171 of cities_df | east haven
# City not found. Skipping...
# Processing Record 173 of cities_df | ruda slaska
# Processing Record 174 of cities_df | ilulissat
# Processing Record 175 of cities_df | nyirbogat
# Processing Record 176 of cities_df | luna
# Processing Record 177 of cities_df | port moresby
# Processing Record 178 of cities_df | baneasa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 181 of cities_df | burdeos
# Processing Record 182 of cities_df | masaguisi
# Processing Record 183 of cities_df | jakarta
# Processing Record 184 of cities_df | monterey park
# Processing Record 185 of cities_df | dauin
# City not found. Skipping...
# Processing Record 187 of cities_df | ciprian porumbescu
# Processing Record 188 of cities_df | bentley
# Processing Record 189 of cities_df | svilengrad
# Processing Record 190 of cities_df | auriflama
# Processing Record 191 of cities_df | lifford
# Processing Record 192 of cities_df | buncrana
# Processing Record 193 of cities_df | otteveny
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 196 of cities_df | san pedro de tutule
# Processing Record 197 of cities_df | basa
# Processing Record 198 of cities_df | barpathar
# Processing Record 199 of cities_df | melle
# Processing Record 200 of cities_df | haebaru
# Processing Record 201 of cities_df | mata de sao joao
# Processing Record 202 of cities_df | merate
# Processing Record 203 of cities_df | mirskoy
# Processing Record 204 of cities_df | agramonte
# Processing Record 205 of cities_df | novopistsovo
# Processing Record 206 of cities_df | el coco
# Processing Record 207 of cities_df | bradenton
# Processing Record 208 of cities_df | hialeah
# Processing Record 209 of cities_df | capela
# Processing Record 210 of cities_df | boteni
# Processing Record 211 of cities_df | juigalpa
# Processing Record 212 of cities_df | jining
# Processing Record 213 of cities_df | gappal
# City not found. Skipping...
# Processing Record 215 of cities_df | ossora
# Processing Record 216 of cities_df | ingenio
# Processing Record 217 of cities_df | sotik
# Processing Record 218 of cities_df | sidhauli
# Processing Record 219 of cities_df | calhoun
# Processing Record 220 of cities_df | mianwali
# Processing Record 221 of cities_df | el mirage
# Processing Record 222 of cities_df | montalto uffugo
# Processing Record 223 of cities_df | buayan
# Processing Record 224 of cities_df | vaculesti
# Processing Record 225 of cities_df | pentaplatanon
# Processing Record 226 of cities_df | margate
# Processing Record 227 of cities_df | dickinson
# Processing Record 228 of cities_df | dhrol
# Processing Record 229 of cities_df | kushmurun
# Processing Record 230 of cities_df | valkenswaard
# Processing Record 231 of cities_df | calimanesti
# Processing Record 232 of cities_df | ponoka
# Processing Record 233 of cities_df | kuchera
# Processing Record 234 of cities_df | bekhtery
# Processing Record 235 of cities_df | mount rainier
# Processing Record 236 of cities_df | fleet
# Processing Record 237 of cities_df | gandu
# Processing Record 238 of cities_df | hemsedal
# Processing Record 239 of cities_df | horasan
# Processing Record 240 of cities_df | velka bites
# Processing Record 241 of cities_df | faridkot
# Processing Record 242 of cities_df | waldoboro
# Processing Record 243 of cities_df | sao joao dos patos
# Processing Record 244 of cities_df | palamos
# Processing Record 245 of cities_df | northbrook
# Processing Record 246 of cities_df | polohy
# Processing Record 247 of cities_df | tawala
# City not found. Skipping...
# Processing Record 249 of cities_df | rustam
# Processing Record 250 of cities_df | la pena
# City not found. Skipping...
# Processing Record 252 of cities_df | tsotilion
# Processing Record 253 of cities_df | bazum
# Processing Record 254 of cities_df | lavara
# Processing Record 255 of cities_df | san juan de la maguana
# Processing Record 256 of cities_df | inverell
# Processing Record 257 of cities_df | san vicente
# Processing Record 258 of cities_df | alandi
# Processing Record 259 of cities_df | liberia
# Processing Record 260 of cities_df | lena
# Processing Record 261 of cities_df | bemban
# Processing Record 262 of cities_df | samayac
# Processing Record 263 of cities_df | izvestkovyy
# Processing Record 264 of cities_df | novo cruzeiro
# Processing Record 265 of cities_df | wa
# Processing Record 266 of cities_df | luxor
# Processing Record 267 of cities_df | weymouth
# Processing Record 268 of cities_df | eyl
# Processing Record 269 of cities_df | obihiro
# Processing Record 270 of cities_df | losinyy
# Processing Record 271 of cities_df | muzaffargarh
# Processing Record 272 of cities_df | tiream
# Processing Record 273 of cities_df | macabugos
# Processing Record 274 of cities_df | riemst
# Processing Record 275 of cities_df | libenge
# Processing Record 276 of cities_df | tarata
# Processing Record 277 of cities_df | union city
# Processing Record 278 of cities_df | vologda
# Processing Record 279 of cities_df | socota
# Processing Record 280 of cities_df | yuty
# Processing Record 281 of cities_df | kyzyl-mazhalyk
# Processing Record 282 of cities_df | ahmadabad
# Processing Record 283 of cities_df | bandarbeyla
# Processing Record 284 of cities_df | karlsruhe
# Processing Record 285 of cities_df | catende
# Processing Record 286 of cities_df | el espinal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 289 of cities_df | oberwart
# Processing Record 290 of cities_df | sisauli
# Processing Record 291 of cities_df | briceni
# Processing Record 292 of cities_df | quebec
# Processing Record 293 of cities_df | bouake
# Processing Record 294 of cities_df | chernitsyno
# Processing Record 295 of cities_df | sampaloc
# City not found. Skipping...
# Processing Record 297 of cities_df | axioupoli
# Processing Record 298 of cities_df | eraclea
# Processing Record 299 of cities_df | bergen op zoom
# Processing Record 300 of cities_df | hinche
# Processing Record 301 of cities_df | buena vista
# Processing Record 302 of cities_df | invercargill
# Processing Record 303 of cities_df | neijiang
# Processing Record 304 of cities_df | trail
# Processing Record 305 of cities_df | uribia
# Processing Record 306 of cities_df | silifke
# Processing Record 307 of cities_df | jonuta
# Processing Record 308 of cities_df | milosesti
# Processing Record 309 of cities_df | karungdong
# Processing Record 310 of cities_df | balud
# Processing Record 311 of cities_df | johannesburg
# Processing Record 312 of cities_df | mayo
# Processing Record 313 of cities_df | malaryta
# Processing Record 314 of cities_df | boyarka
# Processing Record 315 of cities_df | overtown
# Processing Record 316 of cities_df | spasskoye
# Processing Record 317 of cities_df | zahirabad
# Processing Record 318 of cities_df | szczytno
# Processing Record 319 of cities_df | caditaan
# Processing Record 320 of cities_df | primero de enero
# City not found. Skipping...
# Processing Record 322 of cities_df | pilar de la horadada
# Processing Record 323 of cities_df | quechultenango
# Processing Record 324 of cities_df | ames
# Processing Record 325 of cities_df | decines-charpieu
# Processing Record 326 of cities_df | charallave
# Processing Record 327 of cities_df | wadern
# Processing Record 328 of cities_df | iwai
# Processing Record 329 of cities_df | bosanci
# Processing Record 330 of cities_df | makinsk
# Processing Record 331 of cities_df | annur
# Processing Record 332 of cities_df | bratsk
# Processing Record 333 of cities_df | mrgashat
# Processing Record 334 of cities_df | butterworth
# Processing Record 335 of cities_df | teguise
# Processing Record 336 of cities_df | shinuhayr
# Processing Record 337 of cities_df | petaluma
# Processing Record 338 of cities_df | formigine
# Processing Record 339 of cities_df | domazlice
# Processing Record 340 of cities_df | dobrun
# Processing Record 341 of cities_df | sabanalarga
# Processing Record 342 of cities_df | antequera
# Processing Record 343 of cities_df | umm kaddadah
# Processing Record 344 of cities_df | portimao
# Processing Record 345 of cities_df | tilisca
# City not found. Skipping...
# Processing Record 347 of cities_df | sanduleni
# Processing Record 348 of cities_df | tiszafured
# Processing Record 349 of cities_df | aggugaddan
# Processing Record 350 of cities_df | sabalgarh
# Processing Record 351 of cities_df | apaseo el grande
# Processing Record 352 of cities_df | manto
# Processing Record 353 of cities_df | meudon
# Processing Record 354 of cities_df | nyalikungu
# Processing Record 355 of cities_df | leskovik
# Processing Record 356 of cities_df | dillon
# Processing Record 357 of cities_df | nilopolis
# Processing Record 358 of cities_df | nueva concepcion
# Processing Record 359 of cities_df | legnago
# Processing Record 360 of cities_df | chupa
# Processing Record 361 of cities_df | unidad
# Processing Record 362 of cities_df | nizhniy kurkuzhin
# Processing Record 363 of cities_df | vestmannaeyjar
# Processing Record 364 of cities_df | grojdibodu
# Processing Record 365 of cities_df | makir
# Processing Record 366 of cities_df | kranuan
# City not found. Skipping...
# Processing Record 368 of cities_df | mambulo
# Processing Record 369 of cities_df | soest
# Processing Record 370 of cities_df | lingen
# Processing Record 371 of cities_df | simpang
# Processing Record 372 of cities_df | yertarskiy
# Processing Record 373 of cities_df | duarte
# Processing Record 374 of cities_df | villa park
# Processing Record 375 of cities_df | beruwala
# Processing Record 376 of cities_df | dreieich
# Processing Record 377 of cities_df | kabacan
# Processing Record 378 of cities_df | lyss
# Processing Record 379 of cities_df | skalica
# Processing Record 380 of cities_df | osterholz-scharmbeck
# Processing Record 381 of cities_df | west point
# Processing Record 382 of cities_df | chishan
# Processing Record 383 of cities_df | grand-couronne
# Processing Record 384 of cities_df | muzaffarpur
# Processing Record 385 of cities_df | rodeo
# Processing Record 386 of cities_df | southport
# Processing Record 387 of cities_df | poyarkovo
# Processing Record 388 of cities_df | mopti
# Processing Record 389 of cities_df | columbus
# Processing Record 390 of cities_df | sarkikaraagac
# Processing Record 391 of cities_df | langxiang
# Processing Record 392 of cities_df | thunder bay
# Processing Record 393 of cities_df | cativa
# Processing Record 394 of cities_df | florin
# Processing Record 395 of cities_df | lons-le-saunier
# Processing Record 396 of cities_df | murayama
# Processing Record 397 of cities_df | key largo
# Processing Record 398 of cities_df | rincon de tamayo
# Processing Record 399 of cities_df | iwase
# Processing Record 400 of cities_df | bourg-les-valence
# City not found. Skipping...
# Processing Record 402 of cities_df | gesves
# Processing Record 403 of cities_df | radenci
# Processing Record 404 of cities_df | nageshwari
# Processing Record 405 of cities_df | stanisesti
# City not found. Skipping...
# Processing Record 407 of cities_df | casimiro castillo
# Processing Record 408 of cities_df | xuchang
# Processing Record 409 of cities_df | santa ana
# Processing Record 410 of cities_df | reims
# Processing Record 411 of cities_df | sovetskaya
# Processing Record 412 of cities_df | broscauti
# Processing Record 413 of cities_df | midlothian
# Processing Record 414 of cities_df | pervomayskoye
# Processing Record 415 of cities_df | tavistock
# Processing Record 416 of cities_df | zarcero
# Processing Record 417 of cities_df | nivala
# Processing Record 418 of cities_df | derby
# Processing Record 419 of cities_df | wegrow
# Processing Record 420 of cities_df | quezada
# Processing Record 421 of cities_df | akhisar
# Processing Record 422 of cities_df | glenview
# Processing Record 423 of cities_df | azad shahr
# Processing Record 424 of cities_df | newark
# Processing Record 425 of cities_df | chancay
# Processing Record 426 of cities_df | zhemtala
# Processing Record 427 of cities_df | foldes
# Processing Record 428 of cities_df | aliman
# Processing Record 429 of cities_df | howard
# Processing Record 430 of cities_df | ipala
# Processing Record 431 of cities_df | cefalu
# Processing Record 432 of cities_df | marquelia
# Processing Record 433 of cities_df | rio abajo
# Processing Record 434 of cities_df | iwamizawa
# Processing Record 435 of cities_df | artyshta
# Processing Record 436 of cities_df | pangani
# Processing Record 437 of cities_df | viisoara
# Processing Record 438 of cities_df | quezon
# Processing Record 439 of cities_df | kerikeri
# Processing Record 440 of cities_df | gostavatu
# Processing Record 441 of cities_df | opotiki
# Processing Record 442 of cities_df | latiano
# Processing Record 443 of cities_df | mataundh
# Processing Record 444 of cities_df | lubang
# Processing Record 445 of cities_df | alanib
# Processing Record 446 of cities_df | teya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 449 of cities_df | sanary-sur-mer
# Processing Record 450 of cities_df | birobidzhan
# Processing Record 451 of cities_df | santa fe
# Processing Record 452 of cities_df | narragansett
# Processing Record 453 of cities_df | lechinkay
# Processing Record 454 of cities_df | sawankhalok
# Processing Record 455 of cities_df | huejuquilla el alto
# Processing Record 456 of cities_df | nargana
# Processing Record 457 of cities_df | bergschenhoek
# Processing Record 458 of cities_df | yangmei
# Processing Record 459 of cities_df | wingene
# Processing Record 460 of cities_df | wesley
# Processing Record 461 of cities_df | maracineni
# Processing Record 462 of cities_df | aylmer
# Processing Record 463 of cities_df | santa catalina sur
# Processing Record 464 of cities_df | kakhovka
# Processing Record 465 of cities_df | podgorica
# Processing Record 466 of cities_df | radovljica
# Processing Record 467 of cities_df | genzano di roma
# Processing Record 468 of cities_df | haikou
# Processing Record 469 of cities_df | ambagarh chauki
# Processing Record 470 of cities_df | monte redondo
# Processing Record 471 of cities_df | quetzaltenango
# Processing Record 472 of cities_df | apac
# Processing Record 473 of cities_df | opalenica
# Processing Record 474 of cities_df | piran
# Processing Record 475 of cities_df | mopipi
# Processing Record 476 of cities_df | ueckermunde
# Processing Record 477 of cities_df | herend
# Processing Record 478 of cities_df | chatham
# Processing Record 479 of cities_df | tindwari
# Processing Record 480 of cities_df | dachau
# Processing Record 481 of cities_df | itabaiana
# Processing Record 482 of cities_df | balaguer
# Processing Record 483 of cities_df | stavanger
# Processing Record 484 of cities_df | shepsi
# Processing Record 485 of cities_df | ringwood
# Processing Record 486 of cities_df | ortakoy
# Processing Record 487 of cities_df | gavrilov-yam
# Processing Record 488 of cities_df | winburg
# Processing Record 489 of cities_df | barsuki
# Processing Record 490 of cities_df | belluru
# Processing Record 491 of cities_df | sumatac
# Processing Record 492 of cities_df | stolnici
# Processing Record 493 of cities_df | tiszadada
# Processing Record 494 of cities_df | el triunfo
# Processing Record 495 of cities_df | suzhou
# Processing Record 496 of cities_df | ayia paraskevi
# Processing Record 497 of cities_df | tran
# Processing Record 498 of cities_df | palestrina
# Processing Record 499 of cities_df | horw
# Processing Record 500 of cities_df | hronov
# Processing Record 501 of cities_df | ghoti
# Processing Record 502 of cities_df | sao pedro
# Processing Record 503 of cities_df | jonesboro
# City not found. Skipping...
# Processing Record 505 of cities_df | san agustin
# Processing Record 506 of cities_df | kosmach
# Processing Record 507 of cities_df | kingsgate
# Processing Record 508 of cities_df | seinajoki
# Processing Record 509 of cities_df | voerde
# Processing Record 510 of cities_df | ocoee
# Processing Record 511 of cities_df | balagtas
# Processing Record 512 of cities_df | bad nenndorf
# Processing Record 513 of cities_df | fasitoouta
# Processing Record 514 of cities_df | dudingen
# Processing Record 515 of cities_df | kurdzhinovo
# City not found. Skipping...
# Processing Record 517 of cities_df | gaffney
# Processing Record 518 of cities_df | arevashat
# Processing Record 519 of cities_df | kargopol
# Processing Record 520 of cities_df | virklund
# Processing Record 521 of cities_df | dor marunt
# Processing Record 522 of cities_df | alibunan
# Processing Record 523 of cities_df | ringkobing
# Processing Record 524 of cities_df | parga
# Processing Record 525 of cities_df | tadpatri
# Processing Record 526 of cities_df | ponte
# Processing Record 527 of cities_df | horia
# Processing Record 528 of cities_df | barraute
# Processing Record 529 of cities_df | teotihuacan
# Processing Record 530 of cities_df | san javier
# Processing Record 531 of cities_df | beasain
# Processing Record 532 of cities_df | netivot
# Processing Record 533 of cities_df | optasi
# Processing Record 534 of cities_df | oudewater
# Processing Record 535 of cities_df | ashitkovo
# Processing Record 536 of cities_df | binghamton
# Processing Record 537 of cities_df | okaihau
# Processing Record 538 of cities_df | kuji
# Processing Record 539 of cities_df | fiche
# Processing Record 540 of cities_df | ozubulu
# Processing Record 541 of cities_df | sertaozinho
# Processing Record 542 of cities_df | calauan
# Processing Record 543 of cities_df | zemst
# Processing Record 544 of cities_df | khonsa
# Processing Record 545 of cities_df | nixa
# Processing Record 546 of cities_df | vozuca
# Processing Record 547 of cities_df | khoy
# Processing Record 548 of cities_df | hadsund
# Processing Record 549 of cities_df | avarua
# Processing Record 550 of cities_df | sanchez
# Processing Record 551 of cities_df | miramar
# Processing Record 552 of cities_df | juayua
# Processing Record 553 of cities_df | pushkino
# Processing Record 554 of cities_df | tamara
# Processing Record 555 of cities_df | san lucas
# Processing Record 556 of cities_df | kharp
# Processing Record 557 of cities_df | asten
# Processing Record 558 of cities_df | nowy tomysl
# Processing Record 559 of cities_df | jagodina
# Processing Record 560 of cities_df | vannes
# Processing Record 561 of cities_df | real
# Processing Record 562 of cities_df | barinas
# Processing Record 563 of cities_df | new hyde park
# Processing Record 564 of cities_df | lamesa
# Processing Record 565 of cities_df | xalmimilulco
# Processing Record 566 of cities_df | nakuru
# Processing Record 567 of cities_df | ylivieska
# Processing Record 568 of cities_df | voiteg
# Processing Record 569 of cities_df | tankhoy
# Processing Record 570 of cities_df | blackford
# Processing Record 571 of cities_df | los andes
# Processing Record 572 of cities_df | jawor
# Processing Record 573 of cities_df | gebze
# Processing Record 574 of cities_df | taft
# Processing Record 575 of cities_df | lincoln
# Processing Record 576 of cities_df | atok
# Processing Record 577 of cities_df | jizan
# Processing Record 578 of cities_df | barra da estiva
# Processing Record 579 of cities_df | kryvyy rih
# Processing Record 580 of cities_df | mantamados
# Processing Record 581 of cities_df | hod hasharon
# Processing Record 582 of cities_df | rylsk
# Processing Record 583 of cities_df | streamwood
# Processing Record 584 of cities_df | urengoy
# Processing Record 585 of cities_df | bisignano
# Processing Record 586 of cities_df | pszczyna
# Processing Record 587 of cities_df | mafinga
# Processing Record 588 of cities_df | turkistan
# Processing Record 589 of cities_df | porrentruy
# Processing Record 590 of cities_df | csemo
# Processing Record 591 of cities_df | occhiobello
# Processing Record 592 of cities_df | cravo norte
# Processing Record 593 of cities_df | hilo
# Processing Record 594 of cities_df | the colony
# Processing Record 595 of cities_df | bom jardim
# Processing Record 596 of cities_df | dunajska streda
# Processing Record 597 of cities_df | vignola
# Processing Record 598 of cities_df | tulca
# Processing Record 599 of cities_df | makow mazowiecki

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv('Cities.csv')
cities_df.head()
# Out:
#    City_ID Country        City   Latitude  Longitude Max Temperature Humidity  \
# 0        0      hu    csengele  46.542336  19.863584              61       52
# 1        1      ir     delijan  33.990500  50.683800           78.12       12
# 2        2      co       colon   1.191167 -76.968500           63.88       72
# 3        3      no  lyngseidet  69.583333  20.216667           42.89       96
# 4        4      pl  trzebiatow  54.059404  15.279377           50.27       87
#
#   Cloudiness Wind Speed        Date
# 0         18       4.36  1631657979
# 1          0       4.12  1631658094
# 2          7       5.26  1631658096
# 3        100        3.2  1631658097
# 4          1       6.31  1631658099

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City_ID          600 non-null    int64
#  1   Country          600 non-null    object
#  2   City             600 non-null    object
#  3   Latitude         600 non-null    float64
#  4   Longitude        600 non-null    float64
#  5   Max Temperature  600 non-null    object
#  6   Humidity         600 non-null    object
#  7   Cloudiness       600 non-null    object
#  8   Wind Speed       600 non-null    object
#  9   Date             600 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 47.0+ KB

# %%
#Convert Temperature, Humidity, Cloudiness, Wind Speed and date to numeric
cities_df['Max Temperature'] = pd.to_numeric(cities_df['Max Temperature'])
cities_df['Humidity'] = pd.to_numeric(cities_df['Humidity'])
cities_df['Cloudiness'] = pd.to_numeric(cities_df['Cloudiness'])
cities_df['Wind Speed'] = pd.to_numeric(cities_df['Wind Speed']) 
cities_df['Date'] = pd.to_numeric(cities_df['Date'])
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City_ID          600 non-null    int64
#  1   Country          600 non-null    object
#  2   City             600 non-null    object
#  3   Latitude         600 non-null    float64
#  4   Longitude        600 non-null    float64
#  5   Max Temperature  570 non-null    float64
#  6   Humidity         570 non-null    float64
#  7   Cloudiness       570 non-null    float64
#  8   Wind Speed       570 non-null    float64
#  9   Date             570 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 47.0+ KB

# %%
#Remove rows with Nan values
cities_df.dropna(inplace=True)
cities_df.head()
# Out:
#    City_ID Country        City   Latitude  Longitude  Max Temperature  \
# 0        0      hu    csengele  46.542336  19.863584            61.00
# 1        1      ir     delijan  33.990500  50.683800            78.12
# 2        2      co       colon   1.191167 -76.968500            63.88
# 3        3      no  lyngseidet  69.583333  20.216667            42.89
# 4        4      pl  trzebiatow  54.059404  15.279377            50.27
#
#    Humidity  Cloudiness  Wind Speed          Date
# 0      52.0        18.0        4.36  1.631658e+09
# 1      12.0         0.0        4.12  1.631658e+09
# 2      72.0         7.0        5.26  1.631658e+09
# 3      96.0       100.0        3.20  1.631658e+09
# 4      87.0         1.0        6.31  1.631658e+09

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 570 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City_ID          570 non-null    int64
#  1   Country          570 non-null    object
#  2   City             570 non-null    object
#  3   Latitude         570 non-null    float64
#  4   Longitude        570 non-null    float64
#  5   Max Temperature  570 non-null    float64
#  6   Humidity         570 non-null    float64
#  7   Cloudiness       570 non-null    float64
#  8   Wind Speed       570 non-null    float64
#  9   Date             570 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
#Remove rows where humidity is > 100% if any exists
cities_df = cities_df.loc[(cities_df['Humidity']<=100)]
cities_df
# Out:
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 1          1      ir           delijan  33.990500  50.683800            78.12
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed          Date
# 0        52.0        18.0        4.36  1.631658e+09
# 1        12.0         0.0        4.12  1.631658e+09
# 2        72.0         7.0        5.26  1.631658e+09
# 3        96.0       100.0        3.20  1.631658e+09
# 4        87.0         1.0        6.31  1.631658e+09
# ..        ...         ...         ...           ...
# 595      94.0        31.0        9.37  1.631659e+09
# 596      78.0         1.0        5.97  1.631659e+09
# 597      55.0        66.0        5.84  1.631659e+09
# 598      63.0         3.0        0.00  1.631659e+09
# 599      67.0        81.0        2.86  1.631659e+09
#
# [570 rows x 10 columns]

# %%
#Create a data frame that will hold data for cities_df quartiles
cities_measures = cities_df.describe()
cities_measures
# Out:
#           City_ID    Latitude   Longitude  Max Temperature    Humidity  \
# count  570.000000  570.000000  570.000000       570.000000  570.000000
# mean   302.861404   29.816030   15.053949        69.802649   74.645614
# std    174.084853   22.974196   72.695669        12.204237   19.743897
# min      0.000000  -46.400000 -171.916667        30.220000    3.000000
# 25%    150.250000   14.510050  -46.287500        62.460000   63.250000
# 50%    305.500000   38.056388   20.208334        70.715000   80.000000
# 75%    454.750000   47.295833   70.013703        77.850000   90.000000
# max    599.000000   69.583333  177.283333       108.320000  100.000000
#
#        Cloudiness  Wind Speed          Date
# count   570.00000  570.000000  5.700000e+02
# mean     55.52807    5.398947  1.631658e+09
# std      39.15267    3.868173  2.029100e+02
# min       0.00000    0.000000  1.631658e+09
# 25%      12.50000    2.777500  1.631658e+09
# 50%      67.00000    4.610000  1.631658e+09
# 75%      96.00000    6.910000  1.631659e+09
# max     100.00000   20.780000  1.631659e+09

# %%
#Calculate IQR and outbounds for humidity to check for outliers
iqr = cities_measures.loc['75%','Humidity'] - cities_measures.loc['25%','Humidity']
upper_limit = cities_measures.loc['75%','Humidity']+(1.5*iqr)
lower_limit = cities_measures.loc['25%','Humidity']-(1.5*iqr)

#Create clean_df where humidity outliers removed
clean_df = cities_df.loc[(cities_df['Humidity']>lower_limit) & (cities_df['Humidity']<upper_limit)]
clean_df
# Out:
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# 5          5      dk         storvorde  57.003916  10.101252            55.33
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed          Date
# 0        52.0        18.0        4.36  1.631658e+09
# 2        72.0         7.0        5.26  1.631658e+09
# 3        96.0       100.0        3.20  1.631658e+09
# 4        87.0         1.0        6.31  1.631658e+09
# 5        94.0        78.0        3.44  1.631658e+09
# ..        ...         ...         ...           ...
# 595      94.0        31.0        9.37  1.631659e+09
# 596      78.0         1.0        5.97  1.631659e+09
# 597      55.0        66.0        5.84  1.631659e+09
# 598      63.0         3.0        0.00  1.631659e+09
# 599      67.0        81.0        2.86  1.631659e+09
#
# [557 rows x 10 columns]

# %%
#Calculate IQR and outbounds for temperature to check for outliers
iqr = cities_measures.loc['75%','Max Temperature'] - cities_measures.loc['25%','Max Temperature']
upper_limit = cities_measures.loc['75%','Max Temperature']+(1.5*iqr)
lower_limit = cities_measures.loc['25%','Max Temperature']-(1.5*iqr)

#update clean_df to remove temperature outliers
clean_df = clean_df.loc[(clean_df['Max Temperature']>lower_limit) & (clean_df['Max Temperature']<upper_limit)]
clean_df
# Out:
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# 5          5      dk         storvorde  57.003916  10.101252            55.33
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed          Date
# 0        52.0        18.0        4.36  1.631658e+09
# 2        72.0         7.0        5.26  1.631658e+09
# 3        96.0       100.0        3.20  1.631658e+09
# 4        87.0         1.0        6.31  1.631658e+09
# 5        94.0        78.0        3.44  1.631658e+09
# ..        ...         ...         ...           ...
# 595      94.0        31.0        9.37  1.631659e+09
# 596      78.0         1.0        5.97  1.631659e+09
# 597      55.0        66.0        5.84  1.631659e+09
# 598      63.0         3.0        0.00  1.631659e+09
# 599      67.0        81.0        2.86  1.631659e+09
#
# [551 rows x 10 columns]

# %%
#Calculate IQR and outbounds for cloudiness to check for outliers
iqr = cities_measures.loc['75%','Cloudiness'] - cities_measures.loc['25%','Cloudiness']
upper_limit = cities_measures.loc['75%','Cloudiness']+(1.5*iqr)
lower_limit = cities_measures.loc['25%','Cloudiness']-(1.5*iqr)

#update clean_df to remove cloudiness outliers
clean_df = clean_df.loc[(clean_df['Cloudiness']>lower_limit) & (clean_df['Cloudiness']<upper_limit)]
clean_df
# Out:
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# 5          5      dk         storvorde  57.003916  10.101252            55.33
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed          Date
# 0        52.0        18.0        4.36  1.631658e+09
# 2        72.0         7.0        5.26  1.631658e+09
# 3        96.0       100.0        3.20  1.631658e+09
# 4        87.0         1.0        6.31  1.631658e+09
# 5        94.0        78.0        3.44  1.631658e+09
# ..        ...         ...         ...           ...
# 595      94.0        31.0        9.37  1.631659e+09
# 596      78.0         1.0        5.97  1.631659e+09
# 597      55.0        66.0        5.84  1.631659e+09
# 598      63.0         3.0        0.00  1.631659e+09
# 599      67.0        81.0        2.86  1.631659e+09
#
# [551 rows x 10 columns]

# %%
#Calculate IQR and outbounds for wind speed to check for outliers
iqr = cities_measures.loc['75%','Wind Speed'] - cities_measures.loc['25%','Wind Speed']
upper_limit = cities_measures.loc['75%','Wind Speed']+(1.5*iqr)
lower_limit = cities_measures.loc['25%','Wind Speed']-(1.5*iqr)

#update clean_df to remove wind speed outliers
clean_df = clean_df.loc[(clean_df['Wind Speed']>lower_limit) & (clean_df['Wind Speed']<upper_limit)]
clean_df
# Out:
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# 5          5      dk         storvorde  57.003916  10.101252            55.33
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed          Date
# 0        52.0        18.0        4.36  1.631658e+09
# 2        72.0         7.0        5.26  1.631658e+09
# 3        96.0       100.0        3.20  1.631658e+09
# 4        87.0         1.0        6.31  1.631658e+09
# 5        94.0        78.0        3.44  1.631658e+09
# ..        ...         ...         ...           ...
# 595      94.0        31.0        9.37  1.631659e+09
# 596      78.0         1.0        5.97  1.631659e+09
# 597      55.0        66.0        5.84  1.631659e+09
# 598      63.0         3.0        0.00  1.631659e+09
# 599      67.0        81.0        2.86  1.631659e+09
#
# [520 rows x 10 columns]

# %%
#Convert Date values to datetime values
clean_df['Date'] = pd.to_datetime(clean_df['Date'], unit='s')
clean_df
# Out:
# C:\Users\tamer\AppData\Local\Temp/ipykernel_12036/975805280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Date'] = pd.to_datetime(clean_df['Date'], unit='s')
#      City_ID Country              City   Latitude  Longitude  Max Temperature  \
# 0          0      hu          csengele  46.542336  19.863584            61.00
# 2          2      co             colon   1.191167 -76.968500            63.88
# 3          3      no        lyngseidet  69.583333  20.216667            42.89
# 4          4      pl        trzebiatow  54.059404  15.279377            50.27
# 5          5      dk         storvorde  57.003916  10.101252            55.33
# ..       ...     ...               ...        ...        ...              ...
# 595      595      br        bom jardim  -7.016667 -46.483333            69.33
# 596      596      sk   dunajska streda  47.983333  17.616667            69.66
# 597      597      it           vignola  44.483333  11.000000            72.81
# 598      598      ro             tulca  46.783333  21.783333            62.64
# 599      599      pl  makow mazowiecki  52.866667  21.100000            58.98
#
#      Humidity  Cloudiness  Wind Speed                Date
# 0        52.0        18.0        4.36 2021-09-14 22:19:39
# 2        72.0         7.0        5.26 2021-09-14 22:21:36
# 3        96.0       100.0        3.20 2021-09-14 22:21:37
# 4        87.0         1.0        6.31 2021-09-14 22:21:39
# 5        94.0        78.0        3.44 2021-09-14 22:21:40
# ..        ...         ...         ...                 ...
# 595      94.0        31.0        9.37 2021-09-14 22:33:20
# 596      78.0         1.0        5.97 2021-09-14 22:33:22
# 597      55.0        66.0        5.84 2021-09-14 22:33:24
# 598      63.0         3.0        0.00 2021-09-14 22:33:25
# 599      67.0        81.0        2.86 2021-09-14 22:33:27
#
# [520 rows x 10 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_df['Latitude']
y_values = clean_df['Max Temperature']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.title('City Latitude vs. Max Temperature (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)
plt.show()

# %% [markdown]
# ##### The scatter plot shows that cities far from the equator are the coldest cities. It gets warmer near the equator, but the scatter plot for 14/9/2021 temperatures doesn't show a strong correlation.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_df['Latitude']
y_values = clean_df['Humidity']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)
plt.show()

# %% [markdown]
# ##### Distribution of humidity is homogeneous, but tends to be above 50% overall on 14/9/2021 as the whole world is either transitioning from summer to winter, or from winter to summer.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_df['Latitude']
y_values = clean_df['Cloudiness']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)
plt.show()

# %% [markdown]
# ##### Cloudiness percentage seems to be more the further cities are from the equator

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_df['Latitude']
y_values = clean_df['Wind Speed']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)
plt.show()

# %% [markdown]
# ##### Wind speed appears to be higher the further a city from the equator

# %% [markdown]
# ## Linear Regression

# %%
northern_df = clean_df.loc[clean_df['Latitude']>=0]
northern_df.head()
# Out:
#    City_ID Country        City   Latitude  Longitude  Max Temperature  \
# 0        0      hu    csengele  46.542336  19.863584            61.00
# 2        2      co       colon   1.191167 -76.968500            63.88
# 3        3      no  lyngseidet  69.583333  20.216667            42.89
# 4        4      pl  trzebiatow  54.059404  15.279377            50.27
# 5        5      dk   storvorde  57.003916  10.101252            55.33
#
#    Humidity  Cloudiness  Wind Speed                Date
# 0      52.0        18.0        4.36 2021-09-14 22:19:39
# 2      72.0         7.0        5.26 2021-09-14 22:21:36
# 3      96.0       100.0        3.20 2021-09-14 22:21:37
# 4      87.0         1.0        6.31 2021-09-14 22:21:39
# 5      94.0        78.0        3.44 2021-09-14 22:21:40

# %%
southern_df = clean_df.loc[clean_df['Latitude']<0]
southern_df.head()
# Out:
#     City_ID Country               City   Latitude   Longitude  \
# 7         7      bw            sefophe -22.183333   27.966667
# 9         9      nz            waitati -45.750000  170.566667
# 12       12      br  santa cruz do sul -29.716667  -52.433333
# 23       23      ug             masaka  -0.312778   31.713056
# 30       30      tz             sirari  -1.233333   34.433333
#
#     Max Temperature  Humidity  Cloudiness  Wind Speed                Date
# 7             71.71      29.0         0.0        6.58 2021-09-14 22:21:42
# 9             49.80      46.0         4.0        0.49 2021-09-14 22:21:45
# 12            68.99      91.0        78.0        9.89 2021-09-14 22:21:48
# 23            66.54      67.0        39.0        5.99 2021-09-14 22:21:59
# 30            64.11      67.0        84.0        2.62 2021-09-14 22:22:07

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Max Temperature']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.title('Northern Hemisphere Latitude vs. Max Temperature (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(10,40),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: -0.6459980111632794

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Max Temperature']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.title('Southern Hemisphere Latitude vs. Max Temperature (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(-25,50),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: 0.6078528472770665

# %% [markdown]
# ##### After separating cities by hemispheres, we can see a strong correlation between latitude and maximum temperature. Max temperature increases as we approach the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Humidity']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere Latitude vs. Humidity (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(0,30),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: -0.13555160749262057

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Humidity']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere Latitude vs. Humidity (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(-45,50),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: 0.04748993749031703

# %% [markdown]
# ##### Although we have a very weak correlation between humidity and latitude, it appears that humidity increases as we approach the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Cloudiness']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere Latitude vs. Cloudiness (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(0,30),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: -0.20957477518712653

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Cloudiness']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere Latitude vs. Cloudiness (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(-40,30),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: 0.0061311126344309715

# %% [markdown]
# ##### The correlation between latitude and cloudiness is weak, especially in the southern hemisphere (Perhaps because we have far less cities represented in the southern hemisphere).
# ##### But in general, it seems that cloudiness increases as we get nearer to the equator (In contrast with what we perceived from the graph showing all cities together)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Latitude']
y_values = northern_df['Wind Speed']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere Latitude vs. Wind Speed (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(0,12),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: 0.04491773827596033

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Latitude']
y_values = southern_df['Wind Speed']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Latitude vs. Wind Speed (14/9/21)')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

#Draw regression line
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_values,y_values)
print(f'The r-value is: {rvalue}')
regress_values = slope*(x_values)+intercept
plt.plot(x_values, regress_values, color = 'r')
line_eq = f'y={str(round(slope,2))}+x+{str(round(intercept,2))}'
plt.annotate(line_eq,(-45,11),fontsize=15, color='r')
plt.show()
# Out:
# The r-value is: 0.07341979779140051

# %% [markdown]
# ##### Wind speed appears to be getting higher as cities are located nearer to the north, with no correlation with the equator.
